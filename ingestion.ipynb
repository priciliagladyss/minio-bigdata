# %%
import sqlalchemy
from sqlalchemy import create_engine, text


engine = create_engine('postgresql://admin:password123@localhost:5432/minilab_db')

setup_sql = """
CREATE TABLE IF NOT EXISTS customers (
    customer_id   INT PRIMARY KEY,
    customer_name VARCHAR(100),
    city          VARCHAR(100),
    age           INT,
    signup_date   DATE
);

INSERT INTO customers VALUES
(1, 'Arif', 'Surabaya', 28, '2023-11-01'), (2, 'Bella', 'Malang', 24, '2023-12-05'),
(3, 'Chandra', 'Jakarta', 35, '2024-01-10'), (4, 'Dina', 'Bandung', 22, '2024-02-15'),
(5, 'Erlan', 'Yogyakarta', 31, '2023-10-20'), (6, 'Farah', 'Semarang', 26, '2024-03-01'),
(7, 'Gani', 'Medan', 40, '2023-09-12'), (8, 'Hesti', 'Makassar', 29, '2024-01-25'),
(9, 'Indra', 'Denpasar', 27, '2024-02-28'), (10, 'Jihan', 'Balikpapan', 23, '2024-04-05'),
(11, 'Kevin', 'Surabaya', 21, '2024-01-15'), (12, 'Laras', 'Jakarta', 33, '2023-12-20'),
(13, 'Miko', 'Bandung', 25, '2024-03-10'), (14, 'Nadia', 'Malang', 30, '2023-11-15'),
(15, 'Oki', 'Yogyakarta', 38, '2024-04-12'), (16, 'Prita', 'Kediri', 20, '2024-02-10'),
(17, 'Raka', 'Blitar', 42, '2023-08-05'), (18, 'Santi', 'Surabaya', 26, '2024-01-05'),
(19, 'Taufik', 'Jakarta', 29, '2024-03-22'), (20, 'Utami', 'Malang', 34, '2023-10-10')
ON CONFLICT (customer_id) DO NOTHING;

CREATE TABLE IF NOT EXISTS products (
    product_id   INT PRIMARY KEY,
    product_name VARCHAR(150),
    category     VARCHAR(100),
    price        INT,
    stock        INT
);

INSERT INTO products VALUES
(1, 'Monitor Gaming Curved 24"', 'Elektronik', 2500000, 10),
(2, 'Webcam Full HD', 'Elektronik', 650000, 25),
(3, 'Microphone USB Condenser', 'Elektronik', 800000, 15),
(4, 'Smart Air Purifier', 'Smart Home', 1800000, 12),
(5, 'Humidifier Diffuser', 'Smart Home', 350000, 40),
(6, 'Smart Door Lock', 'Smart Home', 1200000, 8),
(7, 'Tenda Camping 4 Orang', 'Outdoor', 750000, 20),
(8, 'Sleeping Bag Polar', 'Outdoor', 200000, 50),
(9, 'Kompor Camping Portabel', 'Outdoor', 150000, 30),
(10, 'Air Fryer 3L', 'Dapur', 950000, 15),
(11, 'Timbangan Digital Dapur', 'Dapur', 85000, 100),
(12, 'Set Pisau Keramik', 'Dapur', 250000, 45)
ON CONFLICT (product_id) DO NOTHING;

CREATE TABLE IF NOT EXISTS orders (
    order_id    INT PRIMARY KEY,
    customer_id INT REFERENCES customers(customer_id),
    product_id  INT REFERENCES products(product_id),
    quantity    INT,
    order_date  DATE
);

INSERT INTO orders VALUES
(1,1,1,1,'2024-01-20'), (2,1,2,1,'2024-01-20'), (3,1,3,1,'2024-01-20'),
(4,11,1,1,'2024-02-05'), (5,11,2,1,'2024-02-05'), (6,13,1,1,'2024-03-15'),
(7,13,3,1,'2024-03-15'), (8,2,4,1,'2024-01-10'), (9,2,5,1,'2024-01-10'),
(10,4,4,1,'2024-03-02'), (11,4,5,2,'2024-03-02'), (12,18,4,1,'2024-02-20'),
(13,18,5,1,'2024-02-20'), (14,5,7,1,'2023-11-25'), (15,5,8,2,'2023-11-25'),
(16,5,9,1,'2023-11-25'), (17,14,7,1,'2024-01-15'), (18,14,8,1,'2024-01-15'),
(19,15,7,1,'2024-04-18'), (20,15,9,1,'2024-04-18'), (21,3,10,1,'2024-02-12'),
(22,3,11,1,'2024-02-12'), (23,12,10,1,'2024-01-05'), (24,12,12,1,'2024-01-05'),
(25,20,10,1,'2023-11-30'), (26,20,11,1,'2023-11-30'), (27,6,2,1,'2024-03-10'),
(28,7,6,1,'2023-10-15'), (29,8,5,1,'2024-02-01'), (30,9,8,2,'2024-03-05'),
(31,17,11,2,'2023-09-01'), (32,19,1,1,'2024-04-01'), (33,16,12,1,'2024-02-25')
ON CONFLICT (order_id) DO NOTHING;
"""

with engine.connect() as conn:
    conn.execute(text(setup_sql))
    conn.commit()

print("✅ Database Inisialisasi Berhasil!")
# Out:
# ✅ Database Inisialisasi Berhasil!

# %%
import pandas as pd


# Dataset Products
df_products = pd.DataFrame({
    'product_id': range(1, 13),
    'product_name': [
        'Monitor Gaming Curved 24"', 'Webcam Full HD', 'Microphone USB Condenser', 
        'Smart Air Purifier', 'Humidifier Diffuser', 'Smart Door Lock', 
        'Tenda Camping 4 Orang', 'Sleeping Bag Polar', 'Kompor Camping Portabel', 
        'Air Fryer 3L', 'Timbangan Digital Dapur', 'Set Pisau Keramik'
    ],
    'category': [
        'Elektronik', 'Elektronik', 'Elektronik', 'Smart Home', 'Smart Home', 'Smart Home',
        'Outdoor', 'Outdoor', 'Outdoor', 'Dapur', 'Dapur', 'Dapur'
    ],
    'price': [2500000, 650000, 800000, 1800000, 350000, 1200000, 750000, 200000, 150000, 950000, 85000, 250000],
    'stock': [10, 25, 15, 12, 40, 8, 20, 50, 30, 15, 100, 45]
})

# Simpan semuanya ke CSV
df_products.to_csv('products.csv', index=False)

print("✅ berhasil dibuat!")
# Out:
# ✅ berhasil dibuat!

# %%
import pandas as pd

# 1. Definisikan data sesuai isi INSERT INTO Anda
data_orders = [
    (1,1,1,1,'2024-01-20'), (2,1,2,1,'2024-01-20'), (3,1,3,1,'2024-01-20'),
    (4,11,1,1,'2024-02-05'), (5,11,2,1,'2024-02-05'), (6,13,1,1,'2024-03-15'),
    (7,13,3,1,'2024-03-15'), (8,2,4,1,'2024-01-10'), (9,2,5,1,'2024-01-10'),
    (10,4,4,1,'2024-03-02'), (11,4,5,2,'2024-03-02'), (12,18,4,1,'2024-02-20'),
    (13,18,5,1,'2024-02-20'), (14,5,7,1,'2023-11-25'), (15,5,8,2,'2023-11-25'),
    (16,5,9,1,'2023-11-25'), (17,14,7,1,'2024-01-15'), (18,14,8,1,'2024-01-15'),
    (19,15,7,1,'2024-04-18'), (20,15,9,1,'2024-04-18'), (21,3,10,1,'2024-02-12'),
    (22,3,11,1,'2024-02-12'), (23,12,10,1,'2024-01-05'), (24,12,12,1,'2024-01-05'),
    (25,20,10,1,'2023-11-30'), (26,20,11,1,'2023-11-30'), (27,6,2,1,'2024-03-10'),
    (28,7,6,1,'2023-10-15'), (29,8,5,1,'2024-02-01'), (30,9,8,2,'2024-03-05'),
    (31,17,11,2,'2023-09-01'), (32,19,1,1,'2024-04-01'), (33,16,12,1,'2024-02-25')
]

df_orders = pd.DataFrame(data_orders, columns=['order_id', 'customer_id', 'product_id', 'quantity', 'order_date'])

# 3. Export ke CSV
df_orders.to_excel('orders_source.xlsx', index=False)

print("✅ File 'orders_source.xlsx' berhasil dibuat!")

df_orders.head()
# Out:
# ✅ File 'orders_source.xlsx' berhasil dibuat!
#    order_id  customer_id  product_id  quantity  order_date
# 0         1            1           1         1  2024-01-20
# 1         2            1           2         1  2024-01-20
# 2         3            1           3         1  2024-01-20
# 3         4           11           1         1  2024-02-05
# 4         5           11           2         1  2024-02-05

# %%
from minio import Minio
from minio.error import S3Error
import pandas as pd
import sqlalchemy
import io


client = Minio(
    "localhost:9000",
    access_key="minioadmin", 
    secret_key="password123", 
    secure=False
)

# Buat bucket kalau belum ada
bucket = "minilab-datalake"
if not client.bucket_exists(bucket):
    client.make_bucket(bucket)
    print(f"✅ Bucket '{bucket}' berhasil dibuat!")
else:
    print(f"✅ Bucket '{bucket}' sudah ada!")

# Fungsi upload DataFrame ke MinIO
def upload_to_minio(df, path):
    csv_bytes = df.to_csv(index=False).encode('utf-8')
    client.put_object(
        bucket,
        path,
        data=io.BytesIO(csv_bytes),
        length=len(csv_bytes),
        content_type="text/csv"
    )
    print(f"🚀 Berhasil upload ke: {path} ({len(df)} baris)")

# 2. Koneksi PostgreSQL
engine = sqlalchemy.create_engine('postgresql://admin:password123@localhost:5432/minilab_db')

# --- BAGIAN A: Ingestion dari RDBMS ---
print("\n--- Processing RDBMS Data ---")
# Menarik data dari tabel E-Commerce Anda
df_customers = pd.read_sql("SELECT * FROM customers", engine)
df_products  = pd.read_sql("SELECT * FROM products", engine)
df_orders_db = pd.read_sql("SELECT * FROM orders", engine)

upload_to_minio(df_customers, "raw/rdbms/customersrdbms.csv")
upload_to_minio(df_products,  "raw/rdbms/productsrdbms.csv")
upload_to_minio(df_orders_db, "raw/rdbms/ordersrdbms.csv")

# --- BAGIAN B: Ingestion dari File Lokal (Dataset Berbeda) ---
print("\n--- Processing File Data ---")

# 1. Ingestion dari CSV (Menggunakan file orders_source.csv yang baru Anda buat)
try:
    df_csv = pd.read_csv("products.csv")
    upload_to_minio(df_csv, "raw/csv/products.csv")
except FileNotFoundError:
    print("❌ Error: File 'products.csv' tidak ditemukan!")

# 2. Ingestion dari XLSX (Opsional: Jika Anda punya file excel lain)
# Jika belum ada file .xlsx, Anda bisa skip bagian ini atau buat dummy singkat
try:
    df_xlsx = pd.read_excel("orders_source.xlsx") # Ganti nama file jika ada
    upload_to_minio(df_xlsx, "raw/xlsx/orders.csv")
except Exception as e:
    print(f"⚠️ Ingestion XLSX dilewati karena: {e}")

print("\n🎉 Semua data berhasil di-ingestion ke MinIO!")
# Out:
# ✅ Bucket 'minilab-datalake' sudah ada!
#
# --- Processing RDBMS Data ---
# 🚀 Berhasil upload ke: raw/rdbms/customersrdbms.csv (20 baris)
# 🚀 Berhasil upload ke: raw/rdbms/productsrdbms.csv (12 baris)
# 🚀 Berhasil upload ke: raw/rdbms/ordersrdbms.csv (33 baris)
#
# --- Processing File Data ---
# 🚀 Berhasil upload ke: raw/csv/products.csv (12 baris)
# 🚀 Berhasil upload ke: raw/xlsx/orders.csv (33 baris)
#
# 🎉 Semua data berhasil di-ingestion ke MinIO!
